# %%
import pandas as pd
import pyarrow.parquet as pq
import numpy as np

from chemistry import Atom, Bond, Molecule

# %%
structures = pd.read_feather('../data/structures.feather')
labelled = pd.read_feather('../data/train.feather')
unlabelled = pd.read_feather('../data/test.feather')

# %%
train.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant
# 0                 84.807602
# 1                -11.257000
# 2                -11.254800
# 3                -11.254300
# 4                 84.807404

# %%
labelled.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant
# 0                 84.807602
# 1                -11.257000
# 2                -11.254800
# 3                -11.254300
# 4                 84.807404

# %%
l = labelled.copy()

# %%
l0 = l.merge(structures, left_on=['molecule_name', 'atom_index_0'], right_on=['molecule_name', 'atom_index'], suffixes=('0', '0'))[['x', 'y', 'z']]
l1 = l.merge(structures, left_on=['molecule_name', 'atom_index_1'], right_on=['molecule_name', 'atom_index'], suffixes=('1', '1'))[['x', 'y', 'z']]
d = l0 - l1
d2 = d * d
dist2 = d2.x + d2.y + d2.z
dist = dist2.apply(np.sqrt)
dist.name = 'distance'
merged = l.join(dist)
merged.to_feather('../data/train_with_dist.feather')

# %%
merged
# Out:
#               id     molecule_name  atom_index_0  atom_index_1  type  \
# 0              0  dsgdb9nsd_000001             1             0  1JHC
# 1              1  dsgdb9nsd_000001             1             2  2JHH
# 2              2  dsgdb9nsd_000001             1             3  2JHH
# 3              3  dsgdb9nsd_000001             1             4  2JHH
# 4              4  dsgdb9nsd_000001             2             0  1JHC
# 5              5  dsgdb9nsd_000001             2             3  2JHH
# 6              6  dsgdb9nsd_000001             2             4  2JHH
# 7              7  dsgdb9nsd_000001             3             0  1JHC
# 8              8  dsgdb9nsd_000001             3             4  2JHH
# 9              9  dsgdb9nsd_000001             4             0  1JHC
# 10            10  dsgdb9nsd_000002             1             0  1JHN
# 11            11  dsgdb9nsd_000002             1             2  2JHH
# 12            12  dsgdb9nsd_000002             1             3  2JHH
# ...

# %%
def partition_labelled(labelled, count=None):
    train_frac = 0.7
    
    n_labelled = count if count is not None else len(labelled)
    n_train = int(n_labelled * train_frac)
    n_test = n_labelled - n_train
    indices = np.arange(0, n_labelled)
    np.random.shuffle(indices)
    
    train_indices = indices[0:n_train]
    test_indices = indices[n_train:]
    
    return train_indices, test_indices

def make_io(data, columns, type_index, dist_index):
    n = len(data)
    input = np.zeros((columns, n), dtype='float32')
    output = np.zeros(n, dtype='float32')
    
    for t in type_index:
        input[type_index[t], data.type == t] = 1
        
    input[dist_index] = data.distance
        
    return  input, output
    
    loc0 = np.empty(3, 'float32')
    loc1 = np.empty(3, 'float32')
    
    
    
    
    for i, (rowidx, row) in enumerate(data.iterrows()):
        input[type_index[row.type], i] = 1
        atom0 = structures[(structures.molecule_name == row.molecule_name) & (structures.atom_index == row.atom_index_0)].iloc[0, :]
        atom1 = structures[(structures.molecule_name == row.molecule_name) & (structures.atom_index == row.atom_index_1)].iloc[0, :]
        loc0[:] = atom0.x, atom0.y, atom0.z
        loc1[:] = atom1.x, atom1.y, atom1.z
        dist = np.linalg.norm(loc0 - loc1)
        input[dist_index, i] = dist
        output[i] = row.scalar_coupling_constant
        
    return input, output

def build_data(labelled, count=None):
    train_indices, test_indices = partition_labelled(labelled, count)
    train = labelled.iloc[train_indices, :]
    test = labelled.iloc[test_indices, :]
    
    types = labelled.type.unique()
    
    # Compute column indices
    index = 0
    type_index = {}
    for t in types:
        type_index[t] = index
        index += 1
        
    dist_index = index
    index += 1
    
    columns = index
    
    train_input, train_output = make_io(train, columns, type_index, dist_index)
    
    print()
    print(train_input)
    print(train_output)
    
build_data(merged, 20)
# Out:
#   File "<ipython-input-148-c8f35b647c10>", line 23
#     input[dist_index = data.distance]
#                      ^
# SyntaxError: invalid syntax
