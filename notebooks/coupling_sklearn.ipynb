# %%
# %load_ext autoreload
# %autoreload 2

# %load_ext line_profiler

# %%
import pandas as pd
import numpy as np

import  matplotlib.pyplot as plt
import pickle

from chemistry import Molecule
from util import score
from pprint import pprint

# %%
with open('../data/molecules_enh.pickle', 'rb') as f:
    molecules = pickle.load(f)

# %%
structures = pd.read_feather('../data/structures_enh.feather')
molecules_df = pd.read_feather('../data/molecules.feather')
labelled = pd.read_feather('../data/train.feather')
unlabelled = pd.read_feather('../data/test.feather')

# %%
labelled_enh = labelled.merge(molecules_df, left_on='molecule_name', right_on='molecule_name')
labelled_enh.head(32)
# Out:
#     id     molecule_name  atom_index_0  atom_index_1  type  \
# 0    0  dsgdb9nsd_000001             1             0  1JHC
# 1    1  dsgdb9nsd_000001             1             2  2JHH
# 2    2  dsgdb9nsd_000001             1             3  2JHH
# 3    3  dsgdb9nsd_000001             1             4  2JHH
# 4    4  dsgdb9nsd_000001             2             0  1JHC
# 5    5  dsgdb9nsd_000001             2             3  2JHH
# 6    6  dsgdb9nsd_000001             2             4  2JHH
# 7    7  dsgdb9nsd_000001             3             0  1JHC
# 8    8  dsgdb9nsd_000001             3             4  2JHH
# 9    9  dsgdb9nsd_000001             4             0  1JHC
# 10  10  dsgdb9nsd_000002             1             0  1JHN
# 11  11  dsgdb9nsd_000002             1             2  2JHH
# 12  12  dsgdb9nsd_000002             1             3  2JHH
# 13  13  dsgdb9nsd_000002             2             0  1JHN
# 14  14  dsgdb9nsd_000002             2             3  2JHH
# 15  15  dsgdb9nsd_000002             3             0  1JHN
# 16  16  dsgdb9nsd_000003             1             2  2JHH
# 17  17  dsgdb9nsd_000005             2             0  1JHC
# 18  18  dsgdb9nsd_000005             2             1  2JHN
# 19  19  dsgdb9nsd_000007             2             0  1JHC
# 20  20  dsgdb9nsd_000007             2             1  2JHC
# 21  21  dsgdb9nsd_000007             2             3  2JHH
# 22  22  dsgdb9nsd_000007             2             4  2JHH
# 23  23  dsgdb9nsd_000007             2             5  3JHH
# 24  24  dsgdb9nsd_000007             2             6  3JHH
# 25  25  dsgdb9nsd_000007             2             7  3JHH
# 26  26  dsgdb9nsd_000007             3             0  1JHC
# 27  27  dsgdb9nsd_000007             3             1  2JHC
# 28  28  dsgdb9nsd_000007             3             4  2JHH
# 29  29  dsgdb9nsd_000007             3             5  3JHH
# 30  30  dsgdb9nsd_000007             3             6  3JHH
# 31  31  dsgdb9nsd_000007             3             7  3JHH
#
#     scalar_coupling_constant  nC  nF  nH  nN  nO  nCNOF  nCN  nOF  nAtoms
# 0                  84.807602   1   0   4   0   0      1    1    0       5
# 1                 -11.257000   1   0   4   0   0      1    1    0       5
# 2                 -11.254800   1   0   4   0   0      1    1    0       5
# 3                 -11.254300   1   0   4   0   0      1    1    0       5
# 4                  84.807404   1   0   4   0   0      1    1    0       5
# 5                 -11.254100   1   0   4   0   0      1    1    0       5
# 6                 -11.254800   1   0   4   0   0      1    1    0       5
# 7                  84.809303   1   0   4   0   0      1    1    0       5
# 8                 -11.254300   1   0   4   0   0      1    1    0       5
# 9                  84.809502   1   0   4   0   0      1    1    0       5
# 10                 32.688900   0   0   3   1   0      1    1    0       4
# 11                -11.186600   0   0   3   1   0      1    1    0       4
# 12                -11.175700   0   0   3   1   0      1    1    0       4
# 13                 32.689098   0   0   3   1   0      1    1    0       4
# 14                -11.175800   0   0   3   1   0      1    1    0       4
# 15                 32.690498   0   0   3   1   0      1    1    0       4
# 16                 -9.946410   0   0   2   0   1      1    0    1       3
# 17                171.220001   1   0   1   1   0      2    2    0       3
# 18                  5.182460   1   0   1   1   0      2    2    0       3
# 19                 83.542900   2   0   6   0   0      2    2    0       8
# 20                 -2.378310   2   0   6   0   0      2    2    0       8
# 21                -11.700500   2   0   6   0   0      2    2    0       8
# 22                -11.697900   2   0   6   0   0      2    2    0       8
# 23                  3.252810   2   0   6   0   0      2    2    0       8
# 24                 13.691300   2   0   6   0   0      2    2    0       8
# 25                  3.252050   2   0   6   0   0      2    2    0       8
# 26                 83.541702   2   0   6   0   0      2    2    0       8
# 27                 -2.378620   2   0   6   0   0      2    2    0       8
# 28                -11.699600   2   0   6   0   0      2    2    0       8
# 29                 13.692400   2   0   6   0   0      2    2    0       8
# 30                  3.252530   2   0   6   0   0      2    2    0       8
# 31                  3.252720   2   0   6   0   0      2    2    0       8

# %%
unlabelled_enh = unlabelled.merge(molecules_df, left_on='molecule_name', right_on='molecule_name')
unlabelled_enh.head(32)
# Out:
#          id     molecule_name  atom_index_0  atom_index_1  type  nC  nF  nH  \
# 0   4658147  dsgdb9nsd_000004             2             0  2JHC   2   0   2
# 1   4658148  dsgdb9nsd_000004             2             1  1JHC   2   0   2
# 2   4658149  dsgdb9nsd_000004             2             3  3JHH   2   0   2
# 3   4658150  dsgdb9nsd_000004             3             0  1JHC   2   0   2
# 4   4658151  dsgdb9nsd_000004             3             1  2JHC   2   0   2
# 5   4658152  dsgdb9nsd_000015             3             0  1JHC   2   0   6
# 6   4658153  dsgdb9nsd_000015             3             2  3JHC   2   0   6
# 7   4658154  dsgdb9nsd_000015             3             4  2JHH   2   0   6
# 8   4658155  dsgdb9nsd_000015             3             5  2JHH   2   0   6
# 9   4658156  dsgdb9nsd_000015             4             0  1JHC   2   0   6
# 10  4658157  dsgdb9nsd_000015             4             2  3JHC   2   0   6
# 11  4658158  dsgdb9nsd_000015             4             5  2JHH   2   0   6
# 12  4658159  dsgdb9nsd_000015             5             0  1JHC   2   0   6
# 13  4658160  dsgdb9nsd_000015             5             2  3JHC   2   0   6
# 14  4658161  dsgdb9nsd_000015             6             0  3JHC   2   0   6
# 15  4658162  dsgdb9nsd_000015             6             2  1JHC   2   0   6
# 16  4658163  dsgdb9nsd_000015             6             7  2JHH   2   0   6
# 17  4658164  dsgdb9nsd_000015             6             8  2JHH   2   0   6
# 18  4658165  dsgdb9nsd_000015             7             0  3JHC   2   0   6
# 19  4658166  dsgdb9nsd_000015             7             2  1JHC   2   0   6
# 20  4658167  dsgdb9nsd_000015             7             8  2JHH   2   0   6
# 21  4658168  dsgdb9nsd_000015             8             0  3JHC   2   0   6
# 22  4658169  dsgdb9nsd_000015             8             2  1JHC   2   0   6
# 23  4658170  dsgdb9nsd_000016             3             0  1JHC   3   0   6
# 24  4658171  dsgdb9nsd_000016             3             1  2JHC   3   0   6
# 25  4658172  dsgdb9nsd_000016             3             2  2JHC   3   0   6
# 26  4658173  dsgdb9nsd_000016             3             4  2JHH   3   0   6
# 27  4658174  dsgdb9nsd_000016             3             5  3JHH   3   0   6
# 28  4658175  dsgdb9nsd_000016             3             6  3JHH   3   0   6
# 29  4658176  dsgdb9nsd_000016             3             7  3JHH   3   0   6
# 30  4658177  dsgdb9nsd_000016             3             8  3JHH   3   0   6
# 31  4658178  dsgdb9nsd_000016             4             0  1JHC   3   0   6
#
#     nN  nO  nCNOF  nCN  nOF  nAtoms
# 0    0   0      2    2    0       4
# 1    0   0      2    2    0       4
# 2    0   0      2    2    0       4
# 3    0   0      2    2    0       4
# 4    0   0      2    2    0       4
# 5    0   1      3    2    1       9
# 6    0   1      3    2    1       9
# 7    0   1      3    2    1       9
# 8    0   1      3    2    1       9
# 9    0   1      3    2    1       9
# 10   0   1      3    2    1       9
# 11   0   1      3    2    1       9
# 12   0   1      3    2    1       9
# 13   0   1      3    2    1       9
# 14   0   1      3    2    1       9
# 15   0   1      3    2    1       9
# 16   0   1      3    2    1       9
# 17   0   1      3    2    1       9
# 18   0   1      3    2    1       9
# 19   0   1      3    2    1       9
# 20   0   1      3    2    1       9
# 21   0   1      3    2    1       9
# 22   0   1      3    2    1       9
# 23   0   0      3    3    0       9
# 24   0   0      3    3    0       9
# 25   0   0      3    3    0       9
# 26   0   0      3    3    0       9
# 27   0   0      3    3    0       9
# 28   0   0      3    3    0       9
# 29   0   0      3    3    0       9
# 30   0   0      3    3    0       9
# 31   0   0      3    3    0       9

# %%
len(labelled), len(labelled_enh)
# Out:
# (4658147, 4658147)

# %%
#data_df = labelled[labelled.type == '1JHC'].head(10)
data_df = labelled_enh.head(1000)
train_df, test_df = partition_data(data_df, train_frac=1)
train_df = train_df.copy()
        
model = SKModel(molecules=molecules,
                structures=structures)
model.setup_data(train_df, train_df)
#model.corr(train_df, train_df)

# %%
model.structures.columns
# Out:
# Index(['molecule_name', 'atom_index', 'atom', 'x', 'y', 'z', 'x_mean',
#        'y_mean', 'z_mean', 'dist_to_mean'],
#       dtype='object')

# %%
model.input_df.columns
# Out:
# Index(['id', 'molecule_name', 'atom_index_0', 'atom_index_1', 'type',
#        'scalar_coupling_constant', 'nC', 'nF', 'nH', 'nN', 'nO', 'nCNOF',
#        'nCN', 'nOF', 'nAtoms', 'coupling_distance', 'atom_0', 'atom_1',
#        'coupling_3JHH', 'coupling_3JHN', 'coupling_2JHN', 'coupling_1JHN',
#        'coupling_2JHC', 'coupling_3JHC', 'coupling_2JHH', 'coupling_1JHC',
#        'atom0_F', 'atom0_N', 'atom0_H', 'atom0_O', 'atom0_C', 'atom0_weight',
#        'ai', 'atom0_dist_to_mean', 'atom0_fi', 'atom0_simple_fi',
#        'atom0_force', 'atomN_F', 'atomN_N', 'atomN_H', 'atomN_O', 'atomN_C',
#        'atomN_weight', 'atomN_dist_to_mean', 'atomN_fi', 'atomN_simple_fi',
#        'atomN_force', 'atom1_F', 'atom1_N', 'atom1_H', 'atom1_O', 'atom1_C',
#        'atom1_weight', 'atom1_dist_to_mean', 'atom1_fi', 'atom1_simple_fi',
#        'atom1_force', 'atom2_F', 'atom2_N', 'atom2_H', 'atom2_O', 'atom2_C',
#        'atom2_weight', 'atom2_dist_to_mean', 'atom2_fi', 'atom2_simple_fi',
#        'atom2_force', 'atom3_F', 'atom3_N', 'atom3_H', 'atom3_O', 'atom3_C',
#        'atom3_weight', 'atom3_dist_to_mean', 'atom3_fi', 'atom3_simple_fi',
#        'atom3_force', 'bond01_dist', 'bond01_valency', 'bond01_strength',
#        'bond12_dist', 'bond12_valency', 'bond12_strength', 'bond23_dist',
#        'bond23_valency', 'bond23_strength'],
#       dtype='object')

# %%
model.input_df.dtypes
# Out:
# id                             int32
# molecule_name                 object
# atom_index_0                   int16
# atom_index_1                   int16
# type                        category
# scalar_coupling_constant     float32
# nC                              int8
# nF                              int8
# nH                              int8
# nN                              int8
# nO                              int8
# nCNOF                           int8
# nCN                             int8
# nOF                             int8
# nAtoms                          int8
# coupling_distance            float32
# atom_0                      category
# atom_1                      category
# coupling_3JHH                   int8
# coupling_3JHN                   int8
# coupling_2JHN                   int8
# coupling_1JHN                   int8
# coupling_2JHC                   int8
# coupling_3JHC                   int8
# coupling_2JHH                   int8
# coupling_1JHC                   int8
# atom0_F                         int8
# atom0_N                         int8
# atom0_H                         int8
# atom0_O                         int8
#                               ...
# atom1_force                  float32
# atom2_F                         int8
# atom2_N                         int8
# atom2_H                         int8
# atom2_O                         int8
# atom2_C                         int8
# atom2_weight                    int8
# atom2_dist_to_mean           float32
# atom2_fi                     float32
# atom2_simple_fi              float32
# atom2_force                  float32
# atom3_F                         int8
# atom3_N                         int8
# atom3_H                         int8
# atom3_O                         int8
# atom3_C                         int8
# atom3_weight                    int8
# atom3_dist_to_mean           float32
# atom3_fi                     float32
# atom3_simple_fi              float32
# atom3_force                  float32
# bond01_dist                  float32
# bond01_valency               float32
# bond01_strength              float32
# bond12_dist                  float32
# bond12_valency               float32
# bond12_strength              float32
# bond23_dist                  float32
# bond23_valency               float32
# bond23_strength              float32
# Length: 86, dtype: object

# %%
labelled_enh.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant  nC  nF  nH  nN  nO  nCNOF  nCN  nOF  nAtoms
# 0                 84.807602   1   0   4   0   0      1    1    0       5
# 1                -11.257000   1   0   4   0   0      1    1    0       5
# 2                -11.254800   1   0   4   0   0      1    1    0       5
# 3                -11.254300   1   0   4   0   0      1    1    0       5
# 4                 84.807404   1   0   4   0   0      1    1    0       5

# %%
import itertools

# %%
from models import partition_data
#from models import SKModel, XGBModel, LGBModel, RFModel
from models import SKModel, LGBModel, RFModel

# Model = RFModel
# model_args = dict(n_estimators=100,
#                   criterion='mae',
#                   n_jobs=-1)






Model = LGBModel

# 0.72
# model_args = dict(n_jobs=8,
#                   max_depth=50,
#                   boosting='dart',
#                   num_leaves=900,
#                   min_child_samples=20,
#                   learning_rate=0.2,
#                   n_estimators=1000,
#                   reg_alpha=0.1,
#                   reg_lambda=0.3,
#                   subsample_freq = 1,
#                   subsample = 0.9)

# 0.70
# model_args = dict(n_jobs=8,
#                   boosting='dart',
#                   n_estimators=5000,
#                   max_depth=128,
#                   num_leaves=1000,
#                   learning_rate=0.2)

model_args = dict(n_jobs=8,
                  objective='regression',
                  boosting='dart',
                  n_estimators=5000,
                  max_depth=128,
                  num_leaves=1000,
                  learning_rate=0.2)

# %%
# atom_count_ranges = [(1, 10), (11, 15), (16, 20), (21, 25), (26, 30)]
# C_count_ranges = [(1, 5), (6, 6), (7, 7), (8, 9)]


coupling_types = sorted(labelled_enh.type.unique())[0:1]
def test(data):
    plt.figure(figsize=(25, 25))
#     for i, (t, (min_atoms, max_atoms)) in enumerate(itertools.product(coupling_types, C_count_ranges), 1):
    for i, t in enumerate(coupling_types, 1):    
#         data_df = data[(data.type == t) & (data.nC >= min_atoms) & (data.nC <= max_atoms)]
        data_df = data[data.type == t]

        train_df, test_df = partition_data(data_df)
        
        if len(train_df) < 10 or len(test_df) < 10:
            continue
            
        print(f'Training {len(train_df)} samples for {t}')

        model = Model(dict(molecules=molecules, 
                           structures=structures),
                      model_args)
  
        model.fit(train_df, train_df)
        output, score = model.evaluate(test_df, test_df)
        print(f'{t} score: {score} (trained on {len(train_df)} elements)')
        plt.subplot(3, 3, i)
        plt.plot(test_df.scalar_coupling_constant, output, '*')
        mn = min(test_df.scalar_coupling_constant.min(), output.min())
        mx = min(test_df.scalar_coupling_constant.max(), output.max())
        plt.plot([mn, mx], [mn, mx])
        plt.title(t)
    plt.show()
        
test(labelled_enh.head(50000))
# Out:
# Training 5835 samples for 1JHC
# 1JHC score: 0.6969388789932011 (trained on 5835 elements)

# %%
model.numeric_input_df.loc[:, [f'atom{i}_fi' for i in range(4)]].max()

# %%
def train(data):
    models = {}
    for t in sorted(data.type.unique()):
        train_df = data[data.type == t]
        print(f'Training {len(train_df)} samples for {t}')
        model = LGBModel(dict(molecules=molecules, 
                              structures=structures),
                         dict(n_jobs=8,
                              max_depth=9,
                              boosting_type='gbdt',
                              num_leaves=128,
                              min_child_samples=20,
                              learning_rate=0.2,
                              n_estimators=1000,
                              reg_alpha=0.1,
                              reg_lambda=0.3,
                              subsample_freq = 1,
                              subsample = 0.9))
        models[t] = model
        model.fit(train_df, train_df)
    
    return models

models = train(labelled_enh)

# %%
def predict(data, models):
    out_df = None
    
    for t in sorted(data.type.unique()):
        predict_df = data[data.type == t]
        print(f'Predicting {len(predict_df)} samples for {t}')
        output = models[t].predict(predict_df)
        
        id = predict_df['id']
        out_df_coupling = pd.DataFrame(data={'id':id, 'scalar_coupling_constant':output}, index=predict_df.index)
        
        if out_df is None:
            out_df = out_df_coupling
        else:
            out_df = out_df.append(out_df_coupling).sort_index()

    return out_df.sort_index()
    
#%prun -s cumulative f(unlabelled.head(10000))
prediction = predict(unlabelled_enh, models)

# %%
prediction.head()

# %%
prediction.to_csv('../data/pred.csv',index=False)
